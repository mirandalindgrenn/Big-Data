# %% [markdown]
# # Assignment 3

# %% [markdown]
# # 📘 Deep Learning Assignment
#
# 👥 **Group members:** _Hedda Hultberg, Miranda Lindgren and Cornelia Engman_
# 🗓️ **Deadline:** See Studium
#
# 📤 Submit:
# - Both `.ipynb` and `.pdf` versions
# - Restart and run all cells before exporting
# - Follow the filename format:
# 'GroupNumber_Student1_Student2.ipynb'
#   `42_EbbaBergman_AkshaiParakkalSreenivasan.ipynb`

# %% [markdown]
# ## 🧭 Before You Start
# > ⚠️ **Important:**
# > Before running this notebook, you **must shut down all other notebooks and kernels**.
# > Running multiple notebooks at once can cause memory issues and slowdowns — especially with image data.
# > Use the stop icon (■) in the Jupyter sidebar to shut down any active sessions.
#
# >  **If this notebook doesn't run at any point:**
#   >1. Try rerunning the cell
#   >2. If stuck, interrupt the cell
#   >3. Restart the kernel and run all necessary cells again

# %% [markdown]
# ## Data
# There's a whole thesis written based on this dataset, available here: http://uu.diva-portal.org/smash/get/diva2:1650957/FULLTEXT01.pdf . The thesis then resulted in a paper: https://openaccess.thecvf.com/content_ICCV_2017_workshops/w1/html/Wieslander_Deep_Convolutional_Neural_ICCV_2017_paper.html
#
#
# A quote from Weislander et al. regarding the dataset:
#
# "The cell samples were collected at Södersjukhuset in Stockholm. The patients have mixed genders, are non smoking, some are human papillomavirus (HPV) positive and some are not, and they have an age span of 47-77 years. From each patient samples were collected with a brush that is scraped at areas of interest in the oral cavity. Each scrape is then smeared out on a glass, which is then stained to highlight important cellular structures"
#
# ## Notes
# This assignment is inspired by Phil Harrisons lab for Pharmaceutical Bioinformatics and Sequence Analysis  from 2021
#
# **You are not allowed to use the exact same network and configurations as in these texts, or copy directly from the labs, but you are allowed to use the same base network if you are using transfer learning. The network you use here must be significantly different from any other network you've used in the labs or read about in the paper above**
#
# You may discuss theory with other groups, but not code nor share code. You may not use ChatGPT4 or similar programs to generate a solution, code, nor answers to the questions
#
#  <span style="color:red"> Solutions deemed to similar will be run through a program designed to detect coding plagirism and if flagged you will be reported for plagirism. </span>
#
#  One hand in per group.

# %% [markdown]
#  ## Hand in
#  Hand in one pdf file and one .ipynb file. The notebook must be runnable with the data, any teacher might run the notebook to check that it actually works. Notebooks that do not run will need to be redone without further feedback. You may redo this hand in twice before failing the assignment all togehter.
#
# ## Report structure
#  You must follow the reportstructure to pass the assignment. Notebooks that do not follow the reportstructure will be sent back to be redone without further feedback.
#  The full reporstructure is specified at the end of this notebook

# %% [markdown]
# ## Goal
# Design a neural network that achieves at least 82% balanced accuracy while demonstrating an understanding of the decisions made throughout the process as well as the strengths and limitations of the final model.
#
# ---
#
# ## Tasks
#
# 1. Build a neural network that achieves less than 65% balanced accuracy on the validation set
#
# 2. Build a neural network that achieves at least 82% balanced accuracy on the validation set, demonstrating the
#
#     * Start with an initial model, improve it step by step until you reach the target accuracy
#         *
#     * Show atleast 2 distinct stages of your model
#         * For each stage, clearly describe:
#             - what you changed
#             - why you made that choice
#         * As you build on the previous model you need demonstrate the new improvements based on the lates model. I.e. if the inital model is A, after your first improvement your model is B, then the the next improvement will be made on B (or later), not A.
#         * If you show different stages further apart you need to show the previous stage as well. E.g A->B, D->E
#
#         * If your  model reached the target accuracy with fewer than 2 changes:
#             Continue modifying the model until you have at least two changes in total
#             Reflect on whether later changes improved or worsened performance
#
# 3. Report your final balanced accuracy at the top of the notebook (in the question section)
#
# 4. Answer all questions in the question section

# %% [markdown]
# ## Question section
#
# ### Accuracies
#
# **Total balanced accuracy:**
# The total balanced accuracy for the validation set was 0.8801
# The total balanced accuracy for the test set was 0.8781
#
# **Accuracy per class:**
# The recall for the healthy cells was predicted to 0.83
# The recall for the tumor cells was predicted to 0.93
#
# **Any other measurements you would like to include:**
#
# Balanced accuracy: 0.8801
#
#
#
#              recall
#
#      healthy  0.83
#        tumor  0.93
#
#
# *(For example: precision, recall, F1-score, confusion matrix, etc. Briefly explain why you chose these)*

# %% [markdown]
# ### Questions
#
# **Q1:** If a clinician requires 80% accuracy in their model, would you recommend using the model you have developed? Why or why not?
# (Think about reliability, generalisation, and whether accuracy alone is sufficient.)
#
# **A1:**
# *As our model has an accuracy over 82%, we would probably be able to recommend it to the clinician. There are of course other parameters that need to be considered, such as generalisation and reliability. In this instance, when our model needs to classify images depending on healthy tissue or tumor, the model needs to be reliable in its prediction. That is, the clinician requires a model that produces low amounts of false negatives (we do not want any tumor imaging data to be misclassified as healthy). It's also of high importance that our model is not overfitted, or underfitted. We want our model to be good at generalisation, to make accurate predictions on unseen data. To ensure that the model produces low amounts of false negatives, recall is one of the metrics we evaluated that the model performed well. *
#
#
# **Q2:** Your model went through several changes. Which specific change had the largest impact on performance, and why do you think that was the case?
#
# **A2:**
# *yFor Task 1 we worked with a different kind of model than the one we worked with in Task 2. Therefore the differences in these are not really comparable. The first model we made had a low accuracy, as the task requested. For the second task we chose a different backbone, EfficientNet and thus the model changed entirely. The changes made to improve the model in task 2 were: adding on weights (using the pre-trained version of EfficientNet), adding dropoutlayer (reducing overfitting as it acts as regularization technique) and adding epochs.*
#
# **Q3:** In this dataset, patients were mixed together before splitting the data into training and validation sets. What is the main drawback of this approach?
#
# **A3:**
# *yOne of the main drawbacks with this approach is that the samples from the same patient can end up in both the training and validation set, making the final model recognize specific patients rather than learning real general biological or clinical patterns. This could therefore wrongfully boost the model accuracy when testing in the validation set, as the model is familiar with the patient's sample (from the training set). When testing the model on unseen data, this will generate a worse performance.*
#
# **Q4:** What is a potential benefit of mixing patients before splitting the data?
#
# **A4:**
# *A potential benefit is that both the training and validation sets look more “balanced” and diverse. Depending on if patients have several samples or just one, this will affect the benefits and drawbacks. If the patients only have one sample, then mixing patients before splitting is harmless and no “leakage” will occur*
#
# **Q5:** How might the results change if you instead split the data by patient (i.e. ensuring that cells from the same patient are only in either training or validation, not both)? Explain your reasoning.
#
# **A1:**
# *First, the performance will likely drop due to the model needing to learn actual biological/clinical patterns, instead of relying on patient-specifc “signatures”. Once again, when the training and validation sets contain samples from the same patient, the model will likely recognize those patterns during the validation and inflate the performance. When we remove this, and only have samples from one patient in either training or validation, the accuracy will likely be lower. We will also see more variability across folds and most importantly a more honest and realistic estimate of generalization. The model will become more trustworthy, even though the accuracy might get worse, and it will also be more biologically/clinically meaningful.*
#
# **Q6:** Besides accuracy, what other evaluation metrics could be important for this task, and why?
#
# **A6:**
# *In this case sensitivity/recall is one important evaluation metric, as we do not want to miss a positive case (would then miss a tumor). Balanced accuracy is also good as it accounts for uneven class sizes. F1-score would give us the harmonic mean of precision and recall, which is important if the classes we work with are imbalanced. We could also use AUC-ROC curves, which would evaluate how well the model separates the two different classes (healthy, tumor) across thresholds, does the model predict the classes better than just random chance? Precision could also be used as an evaluation metric, checking how many of the predicted positives are actually positive. That is to evaluate if the model mislabels healthy cells as tumors.*
#
# **Q7:** If your model performs well on the validation set but poorly in a real clinical setting, what could be the reason for this mismatch?
#
# **A7:**
# *The primary reason would probably be that the validation set was not independent, that the patients were mixed before splitting the data into training and validation sets, causing the model to learn patient-specific patterns instead of true biological/clinical ones. Overfitting could also be a reason for this mismatch, where the model learned training patterns rather than actual general biological/clinical. Class imbalance and distribution shift could also be reasons for this. With distribution shift we mean that the real clinical data may differ in disease stage, demographics, sample quality etc. In real clinical data the classes might not be balanced, while the training data might have been, leading to bad predictions.*

# %% [markdown]
# # Set up

# %%
import cv2
import os
import random

import numpy as np
import pandas as pd
import IPython
import matplotlib.pyplot as plt


from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.utils import class_weight

from datetime import datetime

from importlib.machinery import SourceFileLoader

from IPython.display import display, HTML

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, preprocessing
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2026-05-20 14:46:20.143608: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-20 14:46:20.169856: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-05-20 14:46:20.169896: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-20 14:46:20.187346: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Configure GPUs
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
      print("Done setting memory_growth")
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except Exception as e:
    # Memory growth must be set before GPUs have been initialized
    print("If you get this , probably done already")
    # Catch the exception and display a custom HTML message with red text
    message = """There was some problems setting up the GPU,
                 it is probably best to restart kernel and clear
                 all outputs before starting over
              """
    display(HTML(f"<div style='color: red;'><strong>Warning:</strong>{message}</div>"))
    print(e)
# Out:
# Num GPUs Available:  1
# Done setting memory_growth
# 1 Physical GPUs, 1 Logical GPUs
# 2026-05-20 14:46:22.198884: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22352 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:25:00.0, compute capability: 8.6

# %% [markdown]
# # Paths

# %%
current_directory = os.getcwd()
print(current_directory)
# Out:
# /home/jovyan/Labs/Assignments

# %%
base_path = '/home/jovyan/big-data_deeplearning/'  # Students will need to update

assignments_directory = os.path.join(base_path, 'Assignments')

hpv_images_directory = os.path.join(base_path, 'Data', 'HPV')  # Students will need to update

# %%
from load_helpers import load_helpers
helpers, cnn_helper, plot_helper = load_helpers(assignments_directory)

# %% [markdown]
# ### Setup HPV data

# %% [markdown]
# Extract the HPV data  using the HPV_v2_data_prep.ipynb notebook
# You will need to update the directories in that notebook, and the directories below to match

# %%
# directories for our training, validation and test splits
train_directory = os.path.join(hpv_images_directory, 'train')
validation_directory = os.path.join(hpv_images_directory, 'validation')
test_directory = os.path.join(hpv_images_directory, 'test')

# directory with our training healthy cell images
train_healthy_directory = os.path.join(train_directory, 'healthy')

# directory with our training tumor cell images
train_tumor_directory = os.path.join(train_directory, 'tumor')

# directory with our validation healthy cell images
validation_healthy_directory = os.path.join(validation_directory, 'healthy')

# directory with our validation tumor cell images
validation_tumor_directory = os.path.join(validation_directory, 'tumor')

# directory with our test healthy cell images
test_healthy_directory = os.path.join(test_directory, 'healthy')

# directory with our test tumor cell images
test_tumor_directory = os.path.join(test_directory, 'tumor')

# %%
#### Data check

print('Number of  healthy images for training:', len(os.listdir(train_healthy_directory)))
print('Number of  tumor images for training:', len(os.listdir(train_tumor_directory)))
print('')
print('Number of  healthy images for validation:', len(os.listdir(validation_healthy_directory)))
print('Number of  tumor imagess for validation:', len(os.listdir(validation_tumor_directory)))
print('')
print('Number of  healthy images for testing:', len(os.listdir(test_healthy_directory)))
print('Number of  tumor images for testing:', len(os.listdir(test_tumor_directory)))
# Out:
# Number of  healthy images for training: 1913
# Number of  tumor images for training: 1160
#
# Number of  healthy images for validation: 786
# Number of  tumor imagess for validation: 470
#
# Number of  healthy images for testing: 984
# Number of  tumor images for testing: 621

# %% [markdown]
# > ⚠️ **Important:**
# > **shut down the HPV_v3_data_prep.ipynb notebook**.
# > Running multiple notebooks at once can cause memory issues and slowdowns — especially with image data.
# > Use the stop icon (■) in the Jupyter sidebar to shut down any active sessions.

# %% [markdown]
# ## Plot sample images

# %%
plot_helper.show_random_images_hpv_specific(train_healthy_directory)

# %% [markdown]
# ## Other setup

# %%
# Ändrat grayscale till rgb för att kunna köra efficientnet

# %%
x_len = 96
y_len = 96
batch_size = 32
n_epochs = 10
class_labels=['healthy', 'tumor']

## Note: You might want to change the datagenerators, if so include that in yours steps below,
# ** do not add the changes here unless they're needed for your first model**
# Changes done to make another architecture run will not count as one of the 3 changes you need to make.
train_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=10,
    zoom_range=0.1
)

validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

print('TRAINING DATA:')
train_generator = train_datagen.flow_from_directory(
    train_directory,
    target_size=(x_len, y_len),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='binary'
)

print('')
print('VALIDATION DATA:')
validation_generator = validation_datagen.flow_from_directory(
    validation_directory,
    target_size=(x_len, y_len),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='binary',
    shuffle=False
)

print('')
print('TEST DATA:')
test_generator = test_datagen.flow_from_directory(
    test_directory,
    target_size=(x_len, y_len),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='binary',
    shuffle=False
)

class_weights_array = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)

class_weights = dict(zip(np.unique(train_generator.classes), class_weights_array))
# Out:
# TRAINING DATA:
# Found 3073 images belonging to 2 classes.
#
# VALIDATION DATA:
# Found 1256 images belonging to 2 classes.
#
# TEST DATA:
# Found 1605 images belonging to 2 classes.

# %% [markdown]
# # Functions

# %%
  
def get_image_data_flat_from_file(data_directory, image_paths):
    file_names = image_paths.values.flatten() # Assumes image_paths come in df[image_path_column_name] structure due to lab
    image_data = np.array([np.array(cv2.imread(data_directory + file_name)) for file_name in file_names])
    flattened_image_data = image_data.reshape(image_data.shape[0], -1)
    return flattened_image_data

# %% [markdown]
# # STUDENT CODE BEGINS

# %% [markdown]
# You can add new markdown and code cells in the menues at the top of the notebook interface.

# %% [markdown]
# # Task 1

# %% [markdown]
# ## Baseline Model
#
# This is an fundamental and simple model with low complexity. The simple baseline contains only one convolutional layer, max pooling, flatten layer and one single output neuron. So, intentionally, the model was overall simple so we could evaluate how this architecture performs on the tissuecell dataset before we adding more complexity to the model.
#
# In version 1, the model is quite "aggressive" with one filter. The strides are set to 20, which means that the model looses a big part of the picture. Pooling is used to reduce overfitting of the neural network by reduce computational complexity, but the pooling in this certain model is set too 16x16 which reduces big parts of the image almost instantly. A too large size of pooling can lead to loss of important biological structures and cellular details before the model is able to learn patterns from the two celltypes.
#
# ## Evaluation
# The instructions specified that 65% within the first version of the neural network where our model resulted in around 62% of accuracy in the valdiationset. It's also observed that te balanced accuracy was almost 0,50. In the confusionmatrix, the model shows us predicted samples as healthy tissue and failed to correctly classify tumor cells.
#
# As understood from our results, the accuracy alone is not sufficient for medical classification tasks with class imbalance. The poor results are caused by the overly simplistic model with aggressive dimensionality reduction introduced by the large stride and pooling values. The dataset is also imbalanced which can result in that the model might achieves acceptable accurracy trough prediciting the majority class most of the time. To reduce this error in accuracy, we added balanced accuracy, recall, preicsion and F1-score to get a more correct evalutaion of the performance of the model.

# %% [markdown]
# # Start of Code

# %%
cnn_inputs = keras.Input(shape=(96,96,1))
x = layers.Conv2D(1, kernel_size=(9, 9), strides=20,padding='same')(cnn_inputs)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Flatten()(x)
cnn_outputs = layers.Dense(1, activation='sigmoid')(x)

# %%
## Define the model as a keras model
cnn_model = keras.Model(inputs=cnn_inputs, outputs=cnn_outputs, name="cnn_Model_1")

# %%
## We'll use the same generators as above here, so no need to redefine them
## compile model

cnn_model.compile(optimizer=keras.optimizers.Adam(), loss='binary_crossentropy', metrics = ['accuracy'])
cnn_model.summary()
# Out:
# Model: "cnn_Model_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 96, 96, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 5, 5, 1)        │            82 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 2, 2, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             5 │
# ...

# %%
## Actually train model
epochs = 5
history = cnn_model.fit(x=train_generator,
                    validation_data= validation_generator,
                    epochs= epochs
        )
# Out:
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779288384.157470  324736 service.cc:145] XLA service 0x7325440087b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779288384.157562  324736 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2026-05-20 14:46:24.209691: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# ...

# %%
## Plot results
plot_helper.plot_history(history, "CNN")

# %%
## Evaluate model on validation data
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model,
    validation_generator,
    dataset_name="validation data",
    class_names=class_labels
)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step
#
# --- Evaluation on validation data ---
# Accuracy: 0.6258
# Balanced accuracy: 0.5000
# Macro F1 score: 0.3849
# Weighted F1 score: 0.4818
#
#               precision    recall  f1-score   support
#
#      healthy       0.63      1.00      0.77       786
#        tumor       0.00      0.00      0.00       470
#
#     accuracy                           0.63      1256
#    macro avg       0.31      0.50      0.38      1256
# weighted avg       0.39      0.63      0.48      1256
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %% [markdown]
# # Task 2

# %% [markdown]
# # Change in Data Generators (does not count as one of the changes)

# %%
# Change in data generators
train_datagen = ImageDataGenerator(
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=10,
    zoom_range=0.1
)

validation_datagen = ImageDataGenerator()
test_datagen = ImageDataGenerator()

print('TRAINING DATA:')
train_generator = train_datagen.flow_from_directory(
    train_directory,
    target_size=(x_len, y_len),
    batch_size=batch_size,
    color_mode='rgb',
    class_mode='binary'
)

print('')
print('VALIDATION DATA:')
validation_generator = validation_datagen.flow_from_directory(
    validation_directory,
    target_size=(x_len, y_len),
    batch_size=batch_size,
    color_mode='rgb',
    class_mode='binary',
    shuffle=False
)

print('')
print('TEST DATA:')
test_generator = test_datagen.flow_from_directory(
    test_directory,
    target_size=(x_len, y_len),
    batch_size=batch_size,
    color_mode='rgb',
    class_mode='binary',
    shuffle=False
)

class_weights_array = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)

class_weights = dict(zip(np.unique(train_generator.classes), class_weights_array))
# Out:
# TRAINING DATA:
# Found 3073 images belonging to 2 classes.
#
# VALIDATION DATA:
# Found 1256 images belonging to 2 classes.
#
# TEST DATA:
# Found 1605 images belonging to 2 classes.

# %% [markdown]
# # Base Model EfficientNet

# %% [markdown]
# ## Description, Observation and Evaluations
# From the implemented base model, the accuracy was poor and it was determined to implement transfer learning using a pretrained architecture. Training deeper CNN architectures from scratch also required more training time and increased the risk of overfitting due to a limited dataset size. During lab 2, different pretrained backbone architectures were introduced where EfficientNet was one of them. The backbone learns hierarchical features where the model starts with simple patterns such as edges and textures, furthermore identifying important parts of the images that results in a classification. We decided that EfficientNetB0 was a proper model for our dataset due to its good feature extraction. When analysing medical images including a lot of small complex details, it's vital to distinguish these.
#
#
# EfficientNetB0 was used as the backbone network responsible for feature extraction from the HPV cell images. The model input shape was changed from (96, 96, 1) to (96, 96, 3) due to EfficientNet being designed for RGB images. Further the backbone was initialized without weights to test the models capacity of recognizing features and patterns in the given HPV-dataset. The extracted featuremaps were passed through a GlobalAveragePooling2D layer. Additionally a Dense layer with 64 neurons and swish activation was added. This activation function was selected because it’s commonly used together with EfficientNet to provide smooth gradient propagation during training. To determine healthy and tumor cells, sigmoid outputs a probability value between 0 and 1 due to binary classification. Further this model was trained in 5 epochs.

# %% [markdown]
# # Start of Code

# %%
cnn_inputs = keras.Input(shape=(96,96,3))

base_model = keras.applications.EfficientNetB0(
    include_top=False,
    weights=None,
    input_shape=(96,96,3)
)

base_model.trainable = True

x = base_model(cnn_inputs, training=False)

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(64, activation='swish')(x)


cnn_outputs = layers.Dense(1, activation='sigmoid')(x)

cnn_model = keras.Model(
    inputs=cnn_inputs,
    outputs=cnn_outputs,
    name="cnn_Model_EfficientNet"
)

cnn_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

cnn_model.summary()

history = cnn_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=5,
    class_weight=class_weights
)

## Plot results
plot_helper.plot_history(history, "CNN EfficientNet")

## Evaluate model on validation data
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model,
    validation_generator,
    dataset_name="validation data",
    class_names=class_labels
)
# Out:
# Model: "cnn_Model_EfficientNet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 3, 3, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        81,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# # Model 1

# %% [markdown]
# ## Descriptions, Observations and Evaluation
# For the improved version of the base-model, weights were added and base_model.trainable was set to False (instead of True). This choice was made so that the pre-trained settings of EfficientNet could be used. By incorporating the weights, the new model have prior “knowledge” and better pattern-recognition, enabling better feature extraction and in the end a much better prediction accuracy. Without the weights, the base-model had to learn from scratch how to recognize features such as edges and textures. And the model was only trained on the given HPV dataset. This change made a huge impact on the validation accuracy, validating that the addition of weights was a great choice in improvement change.

# %% [markdown]
# # Start of Code

# %%
cnn_inputs_1 = keras.Input(shape=(96,96,3))

base_model_1 = keras.applications.EfficientNetB0(
    include_top=False,
    weights='imagenet', #changed weights from none to imagenet
    input_shape=(96,96,3)
)

base_model_1.trainable = False # changed trainable from True to False

x = base_model_1(cnn_inputs_1, training=False)

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(64, activation='swish')(x)


cnn_outputs_1 = layers.Dense(1, activation='sigmoid')(x)

cnn_model_1 = keras.Model(
    inputs=cnn_inputs_1,
    outputs=cnn_outputs_1,
    name="cnn_Model_EfficientNet_1"
)

cnn_model_1.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

cnn_model_1.summary()

history = cnn_model_1.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=5,
    class_weight=class_weights
)

## Plot results
plot_helper.plot_history(history, "CNN EfficientNet 1")

## Evaluate model on validation data
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model_1,
    validation_generator,
    dataset_name="validation data",
    class_names=class_labels
)
# Out:
# Model: "cnn_Model_EfficientNet_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 3, 3, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │        81,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# # Model 2

# %% [markdown]
# ## Descriptions, Observations and Evaluation
#
# In this model, to improve the previous step, more epochs were added (5 to 20). By increasing the number of epochs, the model gets more opportunities to learn patterns and adjust its weights. This improved the overall accuracy and indicated that more epochs were neccesary.

# %% [markdown]
# # Start of Code

# %%
cnn_inputs_2 = keras.Input(shape=(96,96,3))

base_model_2 = keras.applications.EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_shape=(96,96,3)
)

base_model_2.trainable = False

x = base_model_2(cnn_inputs_2, training=False)

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(64, activation='swish')(x)


cnn_outputs_2 = layers.Dense(1, activation='sigmoid')(x)

cnn_model_2 = keras.Model(
    inputs=cnn_inputs_2,
    outputs=cnn_outputs_2,
    name="cnn_Model_EfficientNet_2"
)

cnn_model_2.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

cnn_model.summary()

history = cnn_model_2.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=20, #changed from 5 to 20 epochs
    class_weight=class_weights
)

## Plot results
plot_helper.plot_history(history, "CNN EfficientNet")

## Evaluate model on validation data
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model_2,
    validation_generator,
    dataset_name="validation data",
    class_names=class_labels
)
# Out:
# Model: "cnn_Model_EfficientNet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 3, 3, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        81,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# # Model 3

# %% [markdown]
# # Description, Observations and Evaluation
# To improve Model 2, a dropout layer was added. The results from the previous model were already good, but the goal was to improve it even more. Dropout is used to reduce overfitting by randomly deactivating neurons during training, which makes the classification more robust. In this model, dropout was set to 40%, meaning 40% of the neurons is deactivated in each training set.
#
#
# As seen in the results, the accuracy haven't improved. It's high but haven't increased since the previous model. This suggests that adding the dropout layers wasn't useful in our case doe to the model already was accurate and experienced underfitting rather than overfitting. If we'd had overfitting, dropout would probably been improving our results. Instead of dropuot, we could have increased the amount of epochs or optimized the learning rate.

# %% [markdown]
# # Start of Code

# %%
cnn_inputs_3 = keras.Input(shape=(96,96,3))

base_model_3 = keras.applications.EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_shape=(96,96,3)
)

base_model_3.trainable = False

x = base_model_3(cnn_inputs_3, training=False)

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(64, activation='swish')(x)
x = layers.Dropout(0.3)(x) #added dropout layer

cnn_outputs_3 = layers.Dense(1, activation='sigmoid')(x)

cnn_model_3 = keras.Model(
    inputs=cnn_inputs_3,
    outputs=cnn_outputs_3,
    name="cnn_Model_EfficientNet_3"
)

cnn_model_3.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

cnn_model.summary()

history = cnn_model_3.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=20, #changed from 5 to 20 epochs
    class_weight=class_weights
)

## Plot results
plot_helper.plot_history(history, "CNN EfficientNet")

## Evaluate model on validation data
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model_3,
    validation_generator,
    dataset_name="validation data",
    class_names=class_labels
)
# Out:
# Model: "cnn_Model_EfficientNet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 3, 3, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        81,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
## Plot results
plot_helper.plot_history(history, "CNN EfficientNet")

cnn_helper.evaluate_and_plot_model_performance(
    cnn_model_2,
    test_generator,
    dataset_name="test data",
    class_names=class_labels
)
# Out:
#  5/51 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# I0000 00:00:1779289329.635405  345040 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2033', 20 bytes spill stores, 20 bytes spill loads
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 142ms/step
#
# --- Evaluation on test data ---
# Accuracy: 0.8698
# Balanced accuracy: 0.8781
# Macro F1 score: 0.8663
# Weighted F1 score: 0.8712
#
#               precision    recall  f1-score   support
#
#      healthy       0.94      0.84      0.89       984
# ...

# %% [markdown]
# # 🧾 Report Structure
#
# For each task, use the following structure:
#
# ## General structure
# - Use **Markdown cells** to structure and explain your work
# - Use **Code cells** for models, training, and evaluation
# - The **explanation must come before the code** for each model or improvement
# - Avoid vague statements such as “it improved performance” — **quantify your results where possible**
#
# ---
#
# ## Per task
#
# - Markdown cell: **Task number** as a header
# - Markdown cell: **Description of the task**
#     - Describe:
#         - choices made
#         - motivations (for *all* models, not only changes)
#         - reflections on results and any changes made (where appropriate)
#     - See example below for how to structure this
#
# - Markdown cell: **Start of code section**
# - Code cells:
#     - Model definition
#     - Training
#     - Evaluation
#
# - Use **Markdown cells** to clearly separate different parts of your code
#
# ---
#
# ## For each model, include:
#
# - Motivation for the model design (even if it is not a change from a previous model)
# - Model code
# - Comment indicating what part of the model has changed (where appropriate)
# - Validation curves
# - Confusion matrix
# - Accuracy and balanced accuracy
#
#
# ---
#
# ### 🔄 Example: Switching to ELU Activation
# *(Note: You cannot use ELU activation as one of your improvements, nor copy any of this language directly. Plagiarism will be reported.)*
#
# #### Structure of answer
#
# **1. Observation:**
# Training and validation accuracy increased only slowly for cnn_model_1, and there were signs of flat gradients in the first few epochs.
#
# **2. Interpretation:**
# This suggested that the ReLU activations may have led to dead neurons early in training, especially since some of the inputs may have low or negative-valued distributions after normalisation.
#
# **3. Change Made:**
# We replaced ReLU with ELU (Exponential Linear Unit) in all convolutional and dense layers.
#
# **4. Justification:**
# Unlike ReLU, which outputs zero for all negative inputs, ELU allows small negative values. This helps avoid “dead” neurons and encourages more consistent gradient flow during early training. ELU can improve convergence in deeper networks or datasets where feature values include negative ranges.
#
# **5. Short Discussion of Results:**
# With ELU, the training converged slightly faster, and validation accuracy increased more smoothly. This supports the idea that ELU helped mitigate early learning stagnation. It was a worthwhile change for this setting.
#
# ---
#
# #### Answer as text
#
# For cnn_model_1 we observed that both training and validation accuracy improved only gradually during the early epochs. This suggested that some neurons might have become inactive due to the use of ReLU activation. Since ReLU outputs zero for all negative inputs, it can sometimes cause "dead neurons," especially when inputs are close to zero after normalisation.
#
# To address this, we replaced ReLU with ELU (Exponential Linear Unit) in all convolutional and dense layers. ELU allows small negative outputs, which helps preserve gradient flow and prevents early layers from becoming inactive. This change led to slightly faster convergence and a smoother increase in validation accuracy.
#
# The improvement supports the idea that ELU helped reduce early learning stagnation, and it was a suitable choice for this setting.
